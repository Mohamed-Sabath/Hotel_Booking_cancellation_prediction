# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('booking.csv')
Data
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
Data.isnull().sum()
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
columns_to_drop = ['Booking_ID', 'car parking space', 'room type', 'type of meal', 'repeated', 'average price', 'date of reservation']

# Drop the specified columns from the DataFrame
Data = Data.drop(columns=columns_to_drop)

# %%
# Rename columns in your DataFrame
Data.rename(columns={'P-C': 'P_C', 'P-not-C': 'P_not_C'}, inplace=True)

# %%
Data.describe()
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights     lead time           P_C       P_not_C  \
# count           36285.000000  36285.000000  36285.000000  36285.000000
# mean                2.204602     85.239851      0.023343      0.153369
# std                 1.410946     85.938796      0.368281      1.753931
# ...

# %%
Data.shape
# Out:
# (36285, 10)

# %%
sns.boxplot(x=Data['number of adults'])
# Out:
# <AxesSubplot:xlabel='number of adults'>

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="number of adults")
plt.xlabel("booking status")
plt.ylabel("number of adults")
plt.title("Number of adults by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Why we are checking this is, here 2 y labels are in same distributions, but some times those might be with completly different distributions for that particular x variable.. so in that case we can ignore. but here since there are no differences, we have to remove them.

# %%
sns.boxplot(x=Data['number of children'])
# Out:
# <AxesSubplot:xlabel='number of children'>

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="number of children")
plt.xlabel("booking status")
plt.ylabel("number of children")
plt.title("number of children by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.boxplot(x=Data['number of weekend nights'])
# Out:
# <AxesSubplot:xlabel='number of weekend nights'>

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="number of weekend nights")
plt.xlabel("booking status")
plt.ylabel("number of weekend nights")
plt.title("number of weekend nights by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.boxplot(x=Data['number of week nights'])
# Out:
# <AxesSubplot:xlabel='number of week nights'>

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="number of week nights")
plt.xlabel("booking status")
plt.ylabel("number of week nights")
plt.title("number of week nights by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.boxplot(x=Data['lead time'])
# Out:
# <AxesSubplot:xlabel='lead time'>

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="lead time")
plt.xlabel("booking status")
plt.ylabel("lead time")
plt.title("lead time by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# So here we can't touch this

# %%
sns.boxplot(x=Data['P_C'])
# Out:
# <AxesSubplot:xlabel='P_C'>

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="P_C")
plt.xlabel("booking status")
plt.ylabel("P_C")
plt.title("P_C by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %%
out_da = Data[Data['P_C'] > 6]
print("Number of data points in outlier range:", len(out_da))
# Out:
# Number of data points in outlier range: 29

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="P_not_C")
plt.xlabel("booking status")
plt.ylabel("P_not_C")
plt.title("P_not_C by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.boxplot(x=Data['special requests'])
# Out:
# <AxesSubplot:xlabel='special requests'>

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(data=Data, x="booking status", y="special requests")
plt.xlabel("booking status")
plt.ylabel("special requests")
plt.title("special requests by booking status")
 
plt.tight_layout()

# Show the plot
plt.show()

# %%
Data['booking status'].value_counts()
# Out:
# Not_Canceled    24396
# Canceled        11889
# Name: booking status, dtype: int64

# %% [markdown]
# ## It is an imbalanced Dataset

# %%
from sklearn.utils import resample

# Undersample the majority class
not_canceled = Data[Data['booking status'] == 'Not_Canceled']
canceled = Data[Data['booking status'] == 'Canceled']

not_canceled_sampled = resample(not_canceled, replace=False, n_samples=len(canceled), random_state=42)

# Combine the sampled majority class with the minority class
balanced_data = pd.concat([not_canceled_sampled, canceled])

# %%
balanced_data['booking status'].value_counts()
# Out:
# Not_Canceled    11889
# Canceled        11889
# Name: booking status, dtype: int64

# %%
balanced_data['market segment type'].value_counts()
# Out:
# Online           15647
# Offline           6730
# Corporate         1132
# Complementary      185
# Aviation            84
# Name: market segment type, dtype: int64

# %% [markdown]
# Booking_ID
# car parking space
# room type
# type of meal
# repeated
# average price
# date of reservation

# %%
balanced_data.head()
# Out:
#        number of adults  number of children  number of weekend nights  \
# 4657                  2                   0                         0
# 35629                 2                   0                         0
# 21310                 2                   0                         0
# 4307                  2                   0                         3
# 34521                 2                   0                         1
#
#        number of week nights  lead time market segment type  P_C  P_not_C  \
# 4657                       3        131             Offline    0        0
# 35629                      2          1              Online    0        0
# 21310                      3          3              Online    0        0
# 4307                       7        217              Online    0        0
# 34521                      3         56             Offline    0        0
#
#        special requests booking status
# 4657                  3   Not_Canceled
# ...

# %%
balanced_data = balanced_data.reset_index(drop=True)

# %%
balanced_data.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 2                   0                         0
# 1                 2                   0                         0
# 2                 2                   0                         0
# 3                 2                   0                         3
# 4                 2                   0                         1
#
#    number of week nights  lead time market segment type  P_C  P_not_C  \
# 0                      3        131             Offline    0        0
# 1                      2          1              Online    0        0
# 2                      3          3              Online    0        0
# 3                      7        217              Online    0        0
# 4                      3         56             Offline    0        0
#
#    special requests booking status
# 0                 3   Not_Canceled
# 1                 1   Not_Canceled
# 2                 1   Not_Canceled
# ...

# %% [markdown]
# ### Correlationship Analysis

# %%
correlation = balanced_data.corr()
correlation
# Out:
#                           number of adults  number of children  \
# number of adults                  1.000000           -0.022602
# number of children               -0.022602            1.000000
# number of weekend nights          0.072679            0.033370
# number of week nights             0.080737            0.030482
# lead time                         0.098810           -0.060187
# P_C                              -0.040518           -0.014780
# P_not_C                          -0.115439           -0.020425
# special requests                  0.163553            0.106718
#
#                           number of weekend nights  number of week nights  \
# number of adults                          0.072679               0.080737
# number of children                        0.033370               0.030482
# number of weekend nights                  1.000000               0.209552
# number of week nights                     0.209552               1.000000
# ...

# %%
balanced_data['number of adults'].value_counts()
# Out:
# 2    17353
# 1     4756
# 3     1569
# 0       90
# 4       10
# Name: number of adults, dtype: int64

# %%
sb.heatmap(correlation, xticklabels = correlation.columns, yticklabels=correlation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# for the variables called 'p_C' and 'P_not_C' we got 0.45 correlation. which indicates a moderate positive correlation. It's not extremely high so i am not going to remove any here.

# %%
# plt.scatter(balanced_data.P_not_C,balanced_data.P_C)
# sns.set_style("dark")
sns.relplot(data=balanced_data, x="P_not_C", y="P_C")

# %%
plt.rcParams['figure.figsize'] = (9, 6)
plt.style.use('fivethirtyeight')

# Create the countplot
ax = sb.countplot(data=balanced_data, x='market segment type', palette='plasma')

# Add count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.title('Comparison of market segment type', fontweight=30, fontsize=20)
plt.xlabel('Type', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(fontsize=10)

plt.show()

# %%
balanced_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23778 entries, 0 to 23777
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number of adults          23778 non-null  int64
#  1   number of children        23778 non-null  int64
#  2   number of weekend nights  23778 non-null  int64
#  3   number of week nights     23778 non-null  int64
#  4   lead time                 23778 non-null  int64
#  5   market segment type       23778 non-null  object
#  6   P_C                       23778 non-null  int64
#  7   P_not_C                   23778 non-null  int64
#  8   special requests          23778 non-null  int64
#  9   booking status            23778 non-null  object
# dtypes: int64(8), object(2)
# memory usage: 1.8+ MB

# %%
# One hot encoding

import pandas as pd

df = balanced_data.copy()

# Select the columns you want to one-hot encode
columns_to_encode = ['market segment type']

# Use pd.get_dummies to perform one-hot encoding
df = pd.get_dummies(balanced_data, columns=columns_to_encode)

# Now, 'df' contains the original columns along with the one-hot encoded columns

# %%
df.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 2                   0                         0
# 1                 2                   0                         0
# 2                 2                   0                         0
# 3                 2                   0                         3
# 4                 2                   0                         1
#
#    number of week nights  lead time  P_C  P_not_C  special requests  \
# 0                      3        131    0        0                 3
# 1                      2          1    0        0                 1
# 2                      3          3    0        0                 1
# 3                      7        217    0        0                 2
# 4                      3         56    0        0                 0
#
#   booking status  market segment type_Aviation  \
# 0   Not_Canceled                             0
# 1   Not_Canceled                             0
# ...

# %% [markdown]
# ##  Splitting the Data

# %%
x = df.drop('booking status', axis=1)
y = df['booking status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.75,random_state=0)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (17833, 13)
# (17833,)
# (5945, 13)
# (5945,)

# %%
#Scaling the values
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()

x_train = mm.fit_transform(x_train)
x_test = mm.transform(x_test)

# %%
x_train
# Out:
# array([[0.5       , 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.5       , 0.        , 0.14285714, ..., 0.        , 1.        ,
#         0.        ],
#        [0.5       , 0.        , 0.28571429, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.5       , 0.        , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.25      , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.5       , 0.        , 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %% [markdown]
# ## Training the Models

# %%
from sklearn.linear_model import LogisticRegression
# creating a model
model = LogisticRegression()

# feeding the training data to the model
model.fit(x_train, y_train)
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Checking the accuracy
print(round(model.score(x_test,y_test)*100,2),'%')
# Out:
# 77.11 %

# %%
from sklearn.tree import DecisionTreeClassifier
modelDT = DecisionTreeClassifier()

# feeding the training data to the model
modelDT.fit(x_train, y_train)

#Checking the accuracy
print(round(modelDT.score(x_test,y_test)*100,2),'%')
# Out:
# 79.85 %

# %%
from sklearn.svm import SVC
modelSVC = SVC()

# feeding the training data to the model
modelSVC.fit(x_train, y_train)

#Checking the accuracy
print(round(model.score(x_test,y_test)*100,2),'%')
